# %%
import snntorch as snn
from snntorch import surrogate
from snntorch import backprop
from snntorch import functional as SF
from snntorch import utils
from snntorch import spikeplot as splt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import itertools
# Out:
# C:\Users\SHAURYAM DUBEY\AppData\Local\Temp\ipykernel_2492\1406316218.py:3: DeprecationWarning: The module snntorch.backprop will be deprecated in  a future release. Writing out your own training loop will lead to substantially faster performance.
#   from snntorch import backprop

# %%
# Define hyperparameters
batch_size = 64

# Load FER2013 dataset
transform = transforms.Compose([
    transforms.Grayscale(),
    transforms.Resize((48, 48)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    # transforms.ColorJitter(brightness=0.2, contrast=0.2),  # Change brightness and contrast
    # transforms.RandomAffine(degrees=10, translate=(0.1, 0.1)),  # Add small shifts
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# Load the dataset
train_dataset = datasets.ImageFolder(
    root='./dataset/train', transform=transform)
test_dataset = datasets.ImageFolder(
    root='./dataset/test', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False,drop_last=True)

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
for sample in iter(train_loader):
  print("Shape of sample object: ", sample[0].shape)
  break
print(len(train_loader.dataset)%64, len(test_loader.dataset)%64)
# Out:
# Shape of sample object:  torch.Size([64, 1, 48, 48])
# 37 10

# %%
gradient = surrogate.fast_sigmoid(slope=25)
beta = 0.65

# Initializing the network
net = nn.Sequential(nn.Conv2d(1, 32, 3),
                    nn.MaxPool2d(2),
                    snn.Leaky(beta=beta, spike_grad=gradient,
                              init_hidden=True),
                    nn.Conv2d(32, 64, 3),
                    nn.MaxPool2d(2),
                    snn.Leaky(beta=beta, spike_grad=gradient,
                              init_hidden=True),
                    
                    nn.Flatten(),
                    nn.Linear(10*10, 7),
                    snn.Leaky(beta=beta, spike_grad=gradient,
                              init_hidden=True, output=True)
                    ).to(device)

# %%
def forward_pass(net, data):
  spk_rec = []
  snn.utils.reset(net)
  for step in range(data.size(0)):
      spk_out, mem_out = net(data[step])
      spk_rec.append(spk_out)
  return torch.stack(spk_rec)

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.0002, betas=(0.9, 0.999))
loss_fn = SF.mse_count_loss(correct_rate=0.8, incorrect_rate=0.2)

# %%
num_epochs = 50
counter = 0

loss_hist = []
acc_hist = []
test_acc_hist = []

# Training loop
for epoch in range(num_epochs):
    for i, (data, targets) in enumerate(iter(train_loader)):
        # Downsampling image from (128 x 128) to (32 x 32)
        # data = nn.functional.interpolate(data, size=(48, 48))
        data = data.to(device)
        targets = targets.to(device)

        net.train()
        # propagating one batch through the network and evaluating loss
        spk_rec = forward_pass(net, data)
        loss_val = loss_fn(spk_rec, targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        acc = SF.accuracy_rate(spk_rec, targets)
        acc_hist.append(acc)

        # print metrics every so often
        if counter % 16 == 0:
          print(
              f"Epoch {epoch}, Iteration {i} \nTrain Loss: {loss_val.item():.2f}")
          print(f"Train Accuracy: {acc * 100:.2f}%\n")

          correct = 0
          total = 0

          for i, (data, targets) in enumerate(iter(test_loader)):
            # data = nn.functional.interpolate(data, size=(48,48))
            data = data.to(device)
            targets = targets.to(device)
            spk_rec = forward_pass(net, data)
            correct += SF.accuracy_rate(spk_rec, targets) * spk_rec.size(1)
            total += spk_rec.size(1)

          test_acc = (correct/total) * 100
          test_acc_hist.append(test_acc)
          print(f"========== Test Set Accuracy: {test_acc:.2f}% ==========\n")

        counter += 1
# Out:
# Epoch 0, Iteration 0
# Train Loss: 7.73
# Train Accuracy: 14.06%
#
# ========== Test Set Accuracy: 13.36% ==========
#
# Epoch 0, Iteration 16
# Train Loss: 7.73
# Train Accuracy: 14.06%
#
# ========== Test Set Accuracy: 13.36% ==========
#
# Epoch 0, Iteration 32
# Train Loss: 7.73
# Train Accuracy: 9.38%
#
# ========== Test Set Accuracy: 13.32% ==========
#
# Epoch 0, Iteration 48
# Train Loss: 7.72
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 13.18% ==========
#
# Epoch 0, Iteration 64
# Train Loss: 7.67
# Train Accuracy: 17.19%
#
# ========== Test Set Accuracy: 12.50% ==========
#
# Epoch 0, Iteration 80
# Train Loss: 6.62
# Train Accuracy: 6.25%
#
# ========== Test Set Accuracy: 9.03% ==========
#
# Epoch 0, Iteration 96
# Train Loss: 4.44
# Train Accuracy: 1.56%
#
# ========== Test Set Accuracy: 8.90% ==========
#
# Epoch 0, Iteration 112
# Train Loss: 3.17
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 12.49% ==========
#
# Epoch 0, Iteration 128
# Train Loss: 2.88
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 23.45% ==========
#
# Epoch 0, Iteration 144
# Train Loss: 2.86
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.48% ==========
#
# Epoch 0, Iteration 160
# Train Loss: 3.01
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.57% ==========
#
# Epoch 0, Iteration 176
# Train Loss: 2.89
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.55% ==========
#
# Epoch 0, Iteration 192
# Train Loss: 2.84
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.60% ==========
#
# Epoch 0, Iteration 208
# Train Loss: 2.87
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.01% ==========
#
# Epoch 0, Iteration 224
# Train Loss: 2.95
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.14% ==========
#
# Epoch 0, Iteration 240
# Train Loss: 2.82
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 23.48% ==========
#
# Epoch 0, Iteration 256
# Train Loss: 2.88
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 23.37% ==========
#
# Epoch 0, Iteration 272
# Train Loss: 2.88
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 23.21% ==========
#
# Epoch 0, Iteration 288
# Train Loss: 2.81
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 23.05% ==========
#
# Epoch 0, Iteration 304
# Train Loss: 2.84
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 23.12% ==========
#
# Epoch 0, Iteration 320
# Train Loss: 2.94
# Train Accuracy: 17.19%
#
# ========== Test Set Accuracy: 23.54% ==========
#
# Epoch 0, Iteration 336
# Train Loss: 2.88
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.09% ==========
#
# Epoch 0, Iteration 352
# Train Loss: 2.83
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.48% ==========
#
# Epoch 0, Iteration 368
# Train Loss: 2.95
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.55% ==========
#
# Epoch 0, Iteration 384
# Train Loss: 2.81
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.47% ==========
#
# Epoch 0, Iteration 400
# Train Loss: 2.91
# Train Accuracy: 15.62%
#
# ========== Test Set Accuracy: 24.23% ==========
#
# Epoch 0, Iteration 416
# Train Loss: 2.86
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 23.62% ==========
#
# Epoch 0, Iteration 432
# Train Loss: 2.91
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 23.03% ==========
#
# Epoch 1, Iteration 0
# Train Loss: 2.86
# Train Accuracy: 31.25%
#
# ========== Test Set Accuracy: 23.06% ==========
#
# Epoch 1, Iteration 16
# Train Loss: 2.85
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 23.97% ==========
#
# Epoch 1, Iteration 32
# Train Loss: 2.94
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.02% ==========
#
# Epoch 1, Iteration 48
# Train Loss: 2.88
# Train Accuracy: 17.19%
#
# ========== Test Set Accuracy: 23.17% ==========
#
# Epoch 1, Iteration 64
# Train Loss: 2.85
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 22.91% ==========
#
# Epoch 1, Iteration 80
# Train Loss: 2.92
# Train Accuracy: 17.19%
#
# ========== Test Set Accuracy: 22.78% ==========
#
# Epoch 1, Iteration 96
# Train Loss: 2.90
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 22.49% ==========
#
# Epoch 1, Iteration 112
# Train Loss: 2.92
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.08% ==========
#
# Epoch 1, Iteration 128
# Train Loss: 2.79
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 23.72% ==========
#
# Epoch 1, Iteration 144
# Train Loss: 2.91
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 23.67% ==========
#
# Epoch 1, Iteration 160
# Train Loss: 2.77
# Train Accuracy: 35.94%
#
# ========== Test Set Accuracy: 24.36% ==========
#
# Epoch 1, Iteration 176
# Train Loss: 2.91
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.57% ==========
#
# Epoch 1, Iteration 192
# Train Loss: 2.98
# Train Accuracy: 32.81%
#
# ========== Test Set Accuracy: 24.47% ==========
#
# Epoch 1, Iteration 208
# Train Loss: 2.92
# Train Accuracy: 10.94%
#
# ========== Test Set Accuracy: 24.53% ==========
#
# Epoch 1, Iteration 224
# Train Loss: 2.91
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.41% ==========
#
# Epoch 1, Iteration 240
# Train Loss: 2.80
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.58% ==========
#
# Epoch 1, Iteration 256
# Train Loss: 2.82
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.04% ==========
#
# Epoch 1, Iteration 272
# Train Loss: 2.91
# Train Accuracy: 10.94%
#
# ========== Test Set Accuracy: 23.76% ==========
#
# Epoch 1, Iteration 288
# Train Loss: 2.78
# Train Accuracy: 34.38%
#
# ========== Test Set Accuracy: 24.05% ==========
#
# Epoch 1, Iteration 304
# Train Loss: 2.87
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.41% ==========
#
# Epoch 1, Iteration 320
# Train Loss: 2.90
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.62% ==========
#
# Epoch 1, Iteration 336
# Train Loss: 2.80
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.69% ==========
#
# Epoch 1, Iteration 352
# Train Loss: 2.81
# Train Accuracy: 34.38%
#
# ========== Test Set Accuracy: 24.50% ==========
#
# Epoch 1, Iteration 368
# Train Loss: 2.91
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.19% ==========
#
# Epoch 1, Iteration 384
# Train Loss: 2.83
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.39% ==========
#
# Epoch 1, Iteration 400
# Train Loss: 2.80
# Train Accuracy: 31.25%
#
# ========== Test Set Accuracy: 24.40% ==========
#
# Epoch 1, Iteration 416
# Train Loss: 2.76
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.23% ==========
#
# Epoch 1, Iteration 432
# Train Loss: 2.77
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.46% ==========
#
# Epoch 2, Iteration 0
# Train Loss: 2.86
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.30% ==========
#
# Epoch 2, Iteration 16
# Train Loss: 2.96
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 23.79% ==========
#
# Epoch 2, Iteration 32
# Train Loss: 2.78
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 23.88% ==========
#
# Epoch 2, Iteration 48
# Train Loss: 2.81
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.34% ==========
#
# Epoch 2, Iteration 64
# Train Loss: 2.84
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.39% ==========
#
# Epoch 2, Iteration 80
# Train Loss: 2.86
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 24.50% ==========
#
# Epoch 2, Iteration 96
# Train Loss: 2.84
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.60% ==========
#
# Epoch 2, Iteration 112
# Train Loss: 2.85
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.61% ==========
#
# Epoch 2, Iteration 128
# Train Loss: 2.99
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 23.37% ==========
#
# Epoch 2, Iteration 144
# Train Loss: 2.84
# Train Accuracy: 32.81%
#
# ========== Test Set Accuracy: 22.39% ==========
#
# Epoch 2, Iteration 160
# Train Loss: 2.81
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.05% ==========
#
# Epoch 2, Iteration 176
# Train Loss: 2.88
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.47% ==========
#
# Epoch 2, Iteration 192
# Train Loss: 2.89
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.68% ==========
#
# Epoch 2, Iteration 208
# Train Loss: 2.84
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.65% ==========
#
# Epoch 2, Iteration 224
# Train Loss: 2.82
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.58% ==========
#
# Epoch 2, Iteration 240
# Train Loss: 2.91
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.73% ==========
#
# Epoch 2, Iteration 256
# Train Loss: 2.78
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.44% ==========
#
# Epoch 2, Iteration 272
# Train Loss: 2.84
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.51% ==========
#
# Epoch 2, Iteration 288
# Train Loss: 2.80
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.50% ==========
#
# Epoch 2, Iteration 304
# Train Loss: 2.78
# Train Accuracy: 34.38%
#
# ========== Test Set Accuracy: 24.02% ==========
#
# Epoch 2, Iteration 320
# Train Loss: 2.82
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.46% ==========
#
# Epoch 2, Iteration 336
# Train Loss: 2.80
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.65% ==========
#
# Epoch 2, Iteration 352
# Train Loss: 2.77
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.05% ==========
#
# Epoch 2, Iteration 368
# Train Loss: 2.85
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 22.98% ==========
#
# Epoch 2, Iteration 384
# Train Loss: 2.80
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.67% ==========
#
# Epoch 2, Iteration 400
# Train Loss: 2.95
# Train Accuracy: 12.50%
#
# ========== Test Set Accuracy: 24.73% ==========
#
# Epoch 2, Iteration 416
# Train Loss: 2.78
# Train Accuracy: 35.94%
#
# ========== Test Set Accuracy: 24.64% ==========
#
# Epoch 2, Iteration 432
# Train Loss: 2.83
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.67% ==========
#
# Epoch 3, Iteration 0
# Train Loss: 2.78
# Train Accuracy: 32.81%
#
# ========== Test Set Accuracy: 24.09% ==========
#
# Epoch 3, Iteration 16
# Train Loss: 2.85
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.37% ==========
#
# Epoch 3, Iteration 32
# Train Loss: 2.89
# Train Accuracy: 15.62%
#
# ========== Test Set Accuracy: 23.83% ==========
#
# Epoch 3, Iteration 48
# Train Loss: 2.89
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.19% ==========
#
# Epoch 3, Iteration 64
# Train Loss: 2.86
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.55% ==========
#
# Epoch 3, Iteration 80
# Train Loss: 2.82
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.58% ==========
#
# Epoch 3, Iteration 96
# Train Loss: 2.77
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.69% ==========
#
# Epoch 3, Iteration 112
# Train Loss: 2.79
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.60% ==========
#
# Epoch 3, Iteration 128
# Train Loss: 2.80
# Train Accuracy: 31.25%
#
# ========== Test Set Accuracy: 24.46% ==========
#
# Epoch 3, Iteration 144
# Train Loss: 2.87
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.62% ==========
#
# Epoch 3, Iteration 160
# Train Loss: 2.81
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.27% ==========
#
# Epoch 3, Iteration 176
# Train Loss: 2.84
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.40% ==========
#
# Epoch 3, Iteration 192
# Train Loss: 2.88
# Train Accuracy: 17.19%
#
# ========== Test Set Accuracy: 24.43% ==========
#
# Epoch 3, Iteration 208
# Train Loss: 2.88
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.53% ==========
#
# Epoch 3, Iteration 224
# Train Loss: 2.86
# Train Accuracy: 17.19%
#
# ========== Test Set Accuracy: 24.69% ==========
#
# Epoch 3, Iteration 240
# Train Loss: 2.90
# Train Accuracy: 14.06%
#
# ========== Test Set Accuracy: 24.53% ==========
#
# Epoch 3, Iteration 256
# Train Loss: 2.83
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.65% ==========
#
# Epoch 3, Iteration 272
# Train Loss: 2.84
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.75% ==========
#
# Epoch 3, Iteration 288
# Train Loss: 2.85
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.69% ==========
#
# Epoch 3, Iteration 304
# Train Loss: 2.93
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.53% ==========
#
# Epoch 3, Iteration 320
# Train Loss: 2.81
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.34% ==========
#
# Epoch 3, Iteration 336
# Train Loss: 2.92
# Train Accuracy: 15.62%
#
# ========== Test Set Accuracy: 24.07% ==========
#
# Epoch 3, Iteration 352
# Train Loss: 2.86
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 24.39% ==========
#
# Epoch 3, Iteration 368
# Train Loss: 2.87
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.27% ==========
#
# Epoch 3, Iteration 384
# Train Loss: 2.88
# Train Accuracy: 18.75%
#
# ========== Test Set Accuracy: 24.08% ==========
#
# Epoch 3, Iteration 400
# Train Loss: 2.86
# Train Accuracy: 7.81%
#
# ========== Test Set Accuracy: 23.56% ==========
#
# Epoch 3, Iteration 416
# Train Loss: 2.83
# Train Accuracy: 31.25%
#
# ========== Test Set Accuracy: 24.12% ==========
#
# Epoch 3, Iteration 432
# Train Loss: 2.98
# Train Accuracy: 14.06%
#
# ========== Test Set Accuracy: 24.60% ==========
#
# Epoch 4, Iteration 0
# Train Loss: 2.82
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.57% ==========
#
# Epoch 4, Iteration 16
# Train Loss: 2.83
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.71% ==========
#
# Epoch 4, Iteration 32
# Train Loss: 2.84
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.50% ==========
#
# Epoch 4, Iteration 48
# Train Loss: 2.95
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.37% ==========
#
# Epoch 4, Iteration 64
# Train Loss: 2.84
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.47% ==========
#
# Epoch 4, Iteration 80
# Train Loss: 2.86
# Train Accuracy: 15.62%
#
# ========== Test Set Accuracy: 23.65% ==========
#
# Epoch 4, Iteration 96
# Train Loss: 2.85
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 23.52% ==========
#
# Epoch 4, Iteration 112
# Train Loss: 2.82
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.02% ==========
#
# Epoch 4, Iteration 128
# Train Loss: 2.83
# Train Accuracy: 32.81%
#
# ========== Test Set Accuracy: 24.07% ==========
#
# Epoch 4, Iteration 144
# Train Loss: 2.81
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.71% ==========
#
# Epoch 4, Iteration 160
# Train Loss: 2.75
# Train Accuracy: 32.81%
#
# ========== Test Set Accuracy: 24.37% ==========
#
# Epoch 4, Iteration 176
# Train Loss: 2.88
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 24.47% ==========
#
# Epoch 4, Iteration 192
# Train Loss: 2.81
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.83% ==========
#
# Epoch 4, Iteration 208
# Train Loss: 2.82
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.53% ==========
#
# Epoch 4, Iteration 224
# Train Loss: 2.84
# Train Accuracy: 23.44%
#
# ========== Test Set Accuracy: 23.91% ==========
#
# Epoch 4, Iteration 240
# Train Loss: 2.85
# Train Accuracy: 12.50%
#
# ========== Test Set Accuracy: 23.07% ==========
#
# Epoch 4, Iteration 256
# Train Loss: 2.88
# Train Accuracy: 15.62%
#
# ========== Test Set Accuracy: 23.91% ==========
#
# Epoch 4, Iteration 272
# Train Loss: 2.85
# Train Accuracy: 25.00%
#
# ========== Test Set Accuracy: 24.26% ==========
#
# Epoch 4, Iteration 288
# Train Loss: 2.82
# Train Accuracy: 28.12%
#
# ========== Test Set Accuracy: 24.68% ==========
#
# Epoch 4, Iteration 304
# Train Loss: 2.90
# Train Accuracy: 20.31%
#
# ========== Test Set Accuracy: 24.71% ==========
#
# Epoch 4, Iteration 320
# Train Loss: 2.82
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.61% ==========
#
# Epoch 4, Iteration 336
# Train Loss: 2.72
# Train Accuracy: 35.94%
#
# ========== Test Set Accuracy: 24.62% ==========
#
# Epoch 4, Iteration 352
# Train Loss: 2.87
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.67% ==========
#
# Epoch 4, Iteration 368
# Train Loss: 2.79
# Train Accuracy: 32.81%
#
# ========== Test Set Accuracy: 24.55% ==========
#
# Epoch 4, Iteration 384
# Train Loss: 2.78
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.55% ==========
#
# Epoch 4, Iteration 400
# Train Loss: 2.81
# Train Accuracy: 31.25%
#
# ========== Test Set Accuracy: 24.48% ==========
#
# Epoch 4, Iteration 416
# Train Loss: 2.88
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.72% ==========
#
# Epoch 4, Iteration 432
# Train Loss: 2.82
# Train Accuracy: 21.88%
#
# ========== Test Set Accuracy: 24.64% ==========
#
# Epoch 5, Iteration 0
# Train Loss: 2.79
# Train Accuracy: 29.69%
#
# ========== Test Set Accuracy: 24.47% ==========
#
# Epoch 5, Iteration 16
# Train Loss: 2.81
# Train Accuracy: 31.25%
#
# ========== Test Set Accuracy: 24.73% ==========
#
# Epoch 5, Iteration 32
# Train Loss: 2.82
# Train Accuracy: 26.56%
#
# ========== Test Set Accuracy: 24.61% ==========
#
# Epoch 5, Iteration 48
# Train Loss: 2.87
# Train Accuracy: 14.06%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 45
#      43 data = data.to(device)
#      44 targets = targets.to(device)
# ---> 45 spk_rec = forward_pass(net, data)
#      46 correct += SF.accuracy_rate(spk_rec, targets) * spk_rec.size(1)
#      47 total += spk_rec.size(1)
#
# Cell In[12], line 5, in forward_pass(net, data)
#       3 snn.utils.reset(net)
#       4 for step in range(data.size(0)):
# ----> 5     spk_out, mem_out = net(data[step])
#       6     spk_rec.append(spk_out)
#       7 return torch.stack(spk_rec)
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\snntorch\_neurons\leaky.py:210, in Leaky.forward(self, input_, mem)
#     207     self.mem = torch.zeros_like(input_, device=self.mem.device)
#     209 self.reset = self.mem_reset(self.mem)
# --> 210 self.mem = self.state_function(input_)
#     212 if self.state_quant:
#     213     self.mem = self.state_quant(self.mem)
#
# File c:\Users\SHAURYAM DUBEY\Documents\.repo-github\csnn\venv\lib\site-packages\snntorch\_neurons\leaky.py:243, in Leaky._base_sub(self, input_)
#     242 def _base_sub(self, input_):
# --> 243     return self._base_state_function(input_) - self.reset * self.threshold
#
# KeyboardInterrupt:
